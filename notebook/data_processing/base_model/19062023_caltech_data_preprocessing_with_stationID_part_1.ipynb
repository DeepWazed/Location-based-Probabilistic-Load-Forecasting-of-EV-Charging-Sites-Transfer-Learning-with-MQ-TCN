# %% [markdown]
# **Objective:**
#
# We are dealing with multiple `stationID` values occurring at the same `connectionTime` and outliers in the `KWhDelivered`, `total_charging_time`, and `idle_time` variables in this notebook. Also used Isolation Forest for Anomaly Detection.
#
# **Input**: `df_caltech_data_clean_NoUser.csv`
#
# **Output**: `acn_caltech_0.2_0.1_with_stationID_22_06_2023.csv`
#
# **Reference**:`16/03/2023 caltech TCN stationID part-1.ipynb`

# %% [markdown]
# # Mounting and Imports

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/My Drive/TL_A/DeepKale/experiments_0.2/notebook/data_processing/base_model/")
# !ls
# Out:
# 19062023_caltech_data_preprocessing_with_stationID_part_1.ipynb
# 19062023_caltech_jpl_data_preprocessing_without_stationID_part_2.ipynb
# 19062023_jpl_data_preprocessing_with_stationID_part_1.ipynb

# %%
import pandas as pd
import numpy as np
from scipy.interpolate import CubicSpline, interp1d
import scipy.stats as stats
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.ensemble import IsolationForest

SEED = 42
np.random.seed(SEED)

# %% [markdown]
# # Reading the CSV

# %%
df_caltech = pd.read_csv('../../../data/preprocessed/ACN/df_caltech_data_clean_NoUser.csv')

# %%
df_caltech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28184 entries, 0 to 28183
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               28184 non-null  object
#  1   clusterID         28184 non-null  int64
#  2   connectionTime    28184 non-null  object
#  3   disconnectTime    28184 non-null  object
#  4   doneChargingTime  28184 non-null  object
#  5   kWhDelivered      28184 non-null  float64
#  6   sessionID         28184 non-null  object
#  7   siteID            28184 non-null  int64
#  8   spaceID           28184 non-null  object
#  9   stationID         28184 non-null  object
#  10  futility_time     28184 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 2.4+ MB

# %%
df_caltech.shape
# Out:
# (28184, 11)

# %% [markdown]
# `connectionTime` ---> start time when the EV is plugged to the EVSE
# `donechargingTime` ---> when the charging is done
# `disconnectTime` ---> when the EV is disconnected from the EVSE

# %% [markdown]
# **`connectionTime` < `donechargingTime` < `disconnectTime`**

# %%
df_caltech.head()
# Out:
#                         _id  clusterID             connectionTime  \
# 0  5bc90cb9f9af8b0d7fe77cd3         39  2018-04-25 13:45:10+00:00
# 1  5bc90cb9f9af8b0d7fe77cd4         39  2018-04-25 13:45:50+00:00
# 2  5bc90cb9f9af8b0d7fe77cd5         39  2018-04-25 14:37:06+00:00
# 3  5bc90cb9f9af8b0d7fe77cd6         39  2018-04-25 14:40:34+00:00
# 4  5bc90cb9f9af8b0d7fe77cd7         39  2018-04-25 14:43:50+00:00
#
#               disconnectTime           doneChargingTime  kWhDelivered  \
# 0  2018-04-26 00:56:16+00:00  2018-04-25 16:44:15+00:00        10.013
# 1  2018-04-25 23:04:45+00:00  2018-04-25 14:51:44+00:00         5.257
# 2  2018-04-25 23:55:34+00:00  2018-04-25 16:05:22+00:00         5.177
# 3  2018-04-25 23:03:12+00:00  2018-04-25 17:40:30+00:00        10.119
# 4  2018-04-26 01:17:30+00:00  2018-04-25 16:18:28+00:00         7.910
#
#                                 sessionID  siteID spaceID    stationID  \
# 0   2_39_95_27_2018-04-25 13:45:09.617470       2  CA-319   2-39-95-27
# 1  2_39_79_380_2018-04-25 13:45:49.962001       2  CA-489  2-39-79-380
# 2  2_39_79_379_2018-04-25 14:37:06.460772       2  CA-327  2-39-79-379
# 3  2_39_79_381_2018-04-25 14:40:33.638896       2  CA-490  2-39-79-381
# 4  2_39_139_28_2018-04-25 14:43:49.647430       2  CA-303  2-39-139-28
#
#      futility_time
# 0  0 days 08:12:01
# 1  0 days 08:13:01
# 2  0 days 07:50:12
# 3  0 days 05:22:42
# 4  0 days 08:59:02

# %% [markdown]
# # Detailed Analysis and exploration with `StationID`

# %% [markdown]
# **Checking whether the `stationID` and `spaceID` infers the same information or not!**

# %%
# group the dataframe by spaceID and stationID columns and count the number of unique values for stationID in each group
stationID_counts = df_caltech.groupby(['spaceID', 'stationID'])['stationID'].nunique()

# check if there are any groups where stationID has more than one unique value
if (stationID_counts > 1).any():
    print("There are groups where stationID has different values for the same spaceID.")
else:
    print("stationID has the same value for all rows with the same spaceID.")
# Out:
# stationID has the same value for all rows with the same spaceID.

# %% [markdown]
# **Some sanity check**

# %%
# select all rows with spaceID equal to CA-319
df_ca_319 = df_caltech.loc[df_caltech['spaceID'] == 'CA-319']

# display the selected rows
df_ca_319
# Out:
#                             _id  clusterID             connectionTime  \
# 0      5bc90cb9f9af8b0d7fe77cd3         39  2018-04-25 13:45:10+00:00
# 50     5bc90cb9f9af8b0d7fe77d08         39  2018-04-26 02:36:02+00:00
# 57     5bc91212f9af8b0d98ff68cb         39  2018-04-26 13:25:08+00:00
# 102    5bc9153cf9af8b0dad3c05ed         39  2018-04-27 13:16:28+00:00
# 156    5bc91570f9af8b0dad3c0627         39  2018-04-28 16:49:44+00:00
# ...                         ...        ...                        ...
# 27890  613e9d5ef9af8b53e4212168         39  2021-08-27 02:15:39+00:00
# 28046  614d1c1ff9af8b6a7d813ddb         39  2021-09-07 16:46:20+00:00
# 28106  614fbf18f9af8b6e5166421e         39  2021-09-09 21:15:20+00:00
# 28129  6151109bf9af8b707a6c34ae         39  2021-09-10 16:57:17+00:00
# 28175  61550519f9af8b76960e1692         39  2021-09-13 17:40:16+00:00
#
#                   disconnectTime           doneChargingTime  kWhDelivered  \
# 0      2018-04-26 00:56:16+00:00  2018-04-25 16:44:15+00:00        10.013
# 50     2018-04-26 04:38:47+00:00  2018-04-26 04:34:34+00:00        11.891
# 57     2018-04-27 01:17:37+00:00  2018-04-26 16:53:27+00:00        12.138
# 102    2018-04-28 01:10:32+00:00  2018-04-28 01:10:09+00:00        11.323
# 156    2018-04-28 18:52:00+00:00  2018-04-28 18:51:29+00:00         3.242
# ...                          ...                        ...           ...
# 27890  2021-08-27 03:25:48+00:00  2021-08-27 03:19:05+00:00         6.410
# 28046  2021-09-08 01:04:16+00:00  2021-09-07 19:35:52+00:00         9.592
# 28106  2021-09-10 00:22:50+00:00  2021-09-10 00:22:46+00:00        20.406
# 28129  2021-09-10 18:39:38+00:00  2021-09-10 18:39:32+00:00         5.698
# 28175  2021-09-14 01:30:00+00:00  2021-09-13 19:28:06+00:00         6.149
# 28067  2021-09-09 01:35:09+00:00  2021-09-08 18:29:40+00:00        11.958
# 28090  2021-09-09 22:30:31+00:00  2021-09-09 20:56:04+00:00        28.615
# 28123  2021-09-10 23:24:42+00:00  2021-09-10 18:29:20+00:00         8.451
# 28167  2021-09-14 00:20:34+00:00  2021-09-14 00:20:06+00:00        53.024
#
#                                     sessionID  siteID spaceID    stationID  \
# 1      2_39_79_380_2018-04-25 13:45:49.962001       2  CA-489  2-39-79-380
# 40     2_39_79_380_2018-04-26 00:02:15.719927       2  CA-489  2-39-79-380
# 58     2_39_79_380_2018-04-26 13:54:16.774334       2  CA-489  2-39-79-380
# 101    2_39_79_380_2018-04-27 05:06:12.776665       2  CA-489  2-39-79-380
# 111    2_39_79_380_2018-04-27 15:19:26.888099       2  CA-489  2-39-79-380
# ...                                       ...     ...     ...          ...
# 28045  2_39_79_380_2021-09-07 16:41:36.213281       2  CA-489  2-39-79-380
# 28067  2_39_79_380_2021-09-08 16:26:32.474770       2  CA-489  2-39-79-380
# 28090  2_39_79_380_2021-09-09 15:23:43.303502       2  CA-489  2-39-79-380
# 28123  2_39_79_380_2021-09-10 15:32:48.986294       2  CA-489  2-39-79-380
# 28167  2_39_79_380_2021-09-13 15:25:06.629159       2  CA-489  2-39-79-380
#
#          futility_time
# 1      0 days 08:13:01
# 40     0 days 00:10:37
# 58     0 days 00:01:12
# 101    0 days 04:28:53
# 111    0 days 00:16:18
# ...                ...
# 28045  0 days 06:24:29
# 28067  0 days 07:05:29
# 28090  0 days 01:34:27
# 28123  0 days 04:55:22
# 28167  0 days 00:00:28
#
# [843 rows x 11 columns]

# %% [markdown]
# **So we can drop the `spaceID`**

# %%
# drop the 'spaceID' column from the df_caltech dataframe
df_caltech = df_caltech.drop('spaceID', axis=1)

# %%
df_caltech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28184 entries, 0 to 28183
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               28184 non-null  object
#  1   clusterID         28184 non-null  int64
#  2   connectionTime    28184 non-null  object
#  3   disconnectTime    28184 non-null  object
#  4   doneChargingTime  28184 non-null  object
#  5   kWhDelivered      28184 non-null  float64
#  6   sessionID         28184 non-null  object
#  7   siteID            28184 non-null  int64
#  8   stationID         28184 non-null  object
#  9   futility_time     28184 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 2.2+ MB

# %% [markdown]
# **Checking for Unique `StationID`**

# %%
# get all the unique values of the 'stationID' column in the df_caltech dataframe
unique_station_ids = df_caltech['stationID'].unique()

# display the unique values
unique_station_ids
# Out:
# array(['2-39-95-27', '2-39-79-380', '2-39-79-379', '2-39-79-381',
#        '2-39-139-28', '2-39-91-441', '2-39-79-377', '2-39-79-382',
#        '2-39-78-366', '2-39-91-437', '2-39-78-361', '2-39-78-360',
#        '2-39-125-21', '2-39-78-365', '2-39-127-19', '2-39-79-383',
#        '2-39-89-25', '2-39-95-444', '2-39-124-22', '2-39-89-439',
#        '2-39-92-442', '2-39-123-23', '2-39-90-440', '2-39-78-364',
#        '2-39-88-24', '2-39-90-26', '2-39-88-438', '2-39-78-363',
#        '2-39-79-378', '2-39-123-557', '2-39-78-367', '2-39-79-376',
#        '2-39-138-29', '2-39-128-18', '2-39-125-559', '2-39-126-20',
#        '2-39-131-30', '2-39-130-31', '2-39-92-436', '2-39-138-566',
#        '2-39-130-564', '2-39-129-17', '2-39-139-567', '2-39-127-561',
#        '2-39-124-558', '2-39-129-563', '2-39-131-565', '2-39-83-386',
#        '2-39-128-562', '2-39-126-560', '2-39-83-387', '2-39-82-384',
#        '2-39-78-362', '2-39-82-385'], dtype=object)

# %%
df_caltech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28184 entries, 0 to 28183
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               28184 non-null  object
#  1   clusterID         28184 non-null  int64
#  2   connectionTime    28184 non-null  object
#  3   disconnectTime    28184 non-null  object
#  4   doneChargingTime  28184 non-null  object
#  5   kWhDelivered      28184 non-null  float64
#  6   sessionID         28184 non-null  object
#  7   siteID            28184 non-null  int64
#  8   stationID         28184 non-null  object
#  9   futility_time     28184 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 2.2+ MB

# %% [markdown]
# # Some experiments `stationID`

# %%
mask = df_caltech['stationID'].str.strip().str.startswith('2-39', na=False) & (df_caltech['stationID'].str.count('-') == 2)
mask
print(df_caltech['stationID'].unique())
# Out:
# ['2-39-95-27' '2-39-79-380' '2-39-79-379' '2-39-79-381' '2-39-139-28'
#  '2-39-91-441' '2-39-79-377' '2-39-79-382' '2-39-78-366' '2-39-91-437'
#  '2-39-78-361' '2-39-78-360' '2-39-125-21' '2-39-78-365' '2-39-127-19'
#  '2-39-79-383' '2-39-89-25' '2-39-95-444' '2-39-124-22' '2-39-89-439'
#  '2-39-92-442' '2-39-123-23' '2-39-90-440' '2-39-78-364' '2-39-88-24'
#  '2-39-90-26' '2-39-88-438' '2-39-78-363' '2-39-79-378' '2-39-123-557'
#  '2-39-78-367' '2-39-79-376' '2-39-138-29' '2-39-128-18' '2-39-125-559'
#  '2-39-126-20' '2-39-131-30' '2-39-130-31' '2-39-92-436' '2-39-138-566'
#  '2-39-130-564' '2-39-129-17' '2-39-139-567' '2-39-127-561' '2-39-124-558'
#  '2-39-129-563' '2-39-131-565' '2-39-83-386' '2-39-128-562' '2-39-126-560'
#  '2-39-83-387' '2-39-82-384' '2-39-78-362' '2-39-82-385']

# %%
# create a boolean mask of rows where stationID starts with '2-39-'
mask = df_caltech['stationID'].str.startswith('2-39-')

# display the rows where stationID starts with '2-39-'
df_caltech[mask]
# Out:
#                             _id  clusterID             connectionTime  \
# 0      5bc90cb9f9af8b0d7fe77cd3         39  2018-04-25 13:45:10+00:00
# 1      5bc90cb9f9af8b0d7fe77cd4         39  2018-04-25 13:45:50+00:00
# 2      5bc90cb9f9af8b0d7fe77cd5         39  2018-04-25 14:37:06+00:00
# 3      5bc90cb9f9af8b0d7fe77cd6         39  2018-04-25 14:40:34+00:00
# 4      5bc90cb9f9af8b0d7fe77cd7         39  2018-04-25 14:43:50+00:00
# ...                         ...        ...                        ...
# 28179  61550519f9af8b76960e1697         39  2021-09-13 19:43:16+00:00
# 28180  61550519f9af8b76960e1698         39  2021-09-13 19:53:30+00:00
# 28181  61550519f9af8b76960e169a         39  2021-09-13 21:12:53+00:00
# 28182  61550519f9af8b76960e169b         39  2021-09-13 21:17:04+00:00
# 28183  61550519f9af8b76960e169d         39  2021-09-13 23:11:12+00:00
#
#                   disconnectTime           doneChargingTime  kWhDelivered  \
# 0      2018-04-26 00:56:16+00:00  2018-04-25 16:44:15+00:00        10.013
# 1      2018-04-25 23:04:45+00:00  2018-04-25 14:51:44+00:00         5.257
# 2      2018-04-25 23:55:34+00:00  2018-04-25 16:05:22+00:00         5.177
# 3      2018-04-25 23:03:12+00:00  2018-04-25 17:40:30+00:00        10.119
# 4      2018-04-26 01:17:30+00:00  2018-04-25 16:18:28+00:00         7.910
# ...                          ...                        ...           ...
# 28179  2021-09-14 01:34:43+00:00  2021-09-14 00:28:06+00:00        16.370
# 28180  2021-09-13 22:33:34+00:00  2021-09-13 20:56:33+00:00         2.902
# 28181  2021-09-14 00:25:36+00:00  2021-09-13 21:41:31+00:00         2.285
# 28182  2021-09-14 01:01:49+00:00  2021-09-13 23:18:07+00:00         6.715
# 28183  2021-09-14 01:43:11+00:00  2021-09-14 00:13:35+00:00         2.018
#
#                                     sessionID  siteID    stationID  \
# 0       2_39_95_27_2018-04-25 13:45:09.617470       2   2-39-95-27
# 1      2_39_79_380_2018-04-25 13:45:49.962001       2  2-39-79-380
# 2      2_39_79_379_2018-04-25 14:37:06.460772       2  2-39-79-379
# 3      2_39_79_381_2018-04-25 14:40:33.638896       2  2-39-79-381
# 4      2_39_139_28_2018-04-25 14:43:49.647430       2  2-39-139-28
# ...                                       ...     ...          ...
# 28179  2_39_130_31_2021-09-13 19:43:01.675072       2  2-39-130-31
# 28180  2_39_91_437_2021-09-13 19:53:30.351099       2  2-39-91-437
# 28181   2_39_89_25_2021-09-13 21:12:53.318460       2   2-39-89-25
# 28182  2_39_123_23_2021-09-13 21:16:44.026068       2  2-39-123-23
# 28183  2_39_91_437_2021-09-13 23:10:59.528292       2  2-39-91-437
#
#          futility_time
# 0      0 days 08:12:01
# 1      0 days 08:13:01
# 2      0 days 07:50:12
# 3      0 days 05:22:42
# 4      0 days 08:59:02
# ...                ...
# 28179  0 days 01:06:37
# 28180  0 days 01:37:01
# 28181  0 days 02:44:05
# 28182  0 days 01:43:42
# 28183  0 days 01:29:36
#
# [28184 rows x 10 columns]

# %%
# create a boolean mask of rows where the first element of stationID split by '-' is '2' and the second element is '39'
mask = (df_caltech['stationID'].str.split('-', expand=True)[0] == '2') & (df_caltech['stationID'].str.split('-', expand=True)[1] == '39')

# check if all rows satisfy the condition
if mask.all():
    print("All rows in stationID column satisfy the condition")
else:
    print("Not all rows in stationID column satisfy the condition")
# Out:
# All rows in stationID column satisfy the condition

# %% [markdown]
# **So we can remove 2-39 from the `stationID`**

# %%
# create a new column stationID_New by removing '2-39-' from stationID
df_caltech['stationID'] = df_caltech['stationID'].str.replace('2-39-', '')

# print the first 5 rows of the new column
df_caltech.head()
# Out:
#                         _id  clusterID             connectionTime  \
# 0  5bc90cb9f9af8b0d7fe77cd3         39  2018-04-25 13:45:10+00:00
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               28184 non-null  object
#  1   clusterID         28184 non-null  int64
#  2   connectionTime    28184 non-null  object
#  3   disconnectTime    28184 non-null  object
#  4   doneChargingTime  28184 non-null  object
#  5   kWhDelivered      28184 non-null  float64
#  6   sessionID         28184 non-null  object
#  7   siteID            28184 non-null  int64
#  8   stationID         28184 non-null  int64
#  9   futility_time     28184 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 2.2+ MB

# %% [markdown]
# # Timezone correction

# %%
def timezonecorrection(dataframe):
    columns_tobe_converted = ['connectionTime', 'disconnectTime', 'doneChargingTime']

    for column in columns_tobe_converted:
        dataframe[column] = pd.to_datetime(dataframe[column], utc=False, errors='ignore')
        dataframe[column] = dataframe[column].map(lambda x: pd.to_datetime(x, format='%Y-%m-%d %H:%M:%S.%f', yearfirst=True).tz_convert('America/Los_Angeles'))
        dataframe[column] = dataframe[column].dt.strftime('%Y-%m-%d %H:%M:%S.%f')
        dataframe[column] = pd.to_datetime(dataframe[column])

    return dataframe

# %%
caltech_dataframe = df_caltech.copy()
caltech_dataframe = timezonecorrection(caltech_dataframe)
caltech_dataframe
# Out:
#                             _id  clusterID      connectionTime  \
# 0      5bc90cb9f9af8b0d7fe77cd3         39 2018-04-25 06:45:10
# 1      5bc90cb9f9af8b0d7fe77cd4         39 2018-04-25 06:45:50
# 2      5bc90cb9f9af8b0d7fe77cd5         39 2018-04-25 07:37:06
# 3      5bc90cb9f9af8b0d7fe77cd6         39 2018-04-25 07:40:34
# 4      5bc90cb9f9af8b0d7fe77cd7         39 2018-04-25 07:43:50
# ...                         ...        ...                 ...
# 28179  61550519f9af8b76960e1697         39 2021-09-13 12:43:16
# 28180  61550519f9af8b76960e1698         39 2021-09-13 12:53:30
# 28181  61550519f9af8b76960e169a         39 2021-09-13 14:12:53
# 28182  61550519f9af8b76960e169b         39 2021-09-13 14:17:04
# 28183  61550519f9af8b76960e169d         39 2021-09-13 16:11:12
#
#            disconnectTime    doneChargingTime  kWhDelivered  \
# 0     2018-04-25 17:56:16 2018-04-25 09:44:15        10.013
# 1     2018-04-25 16:04:45 2018-04-25 07:51:44         5.257
# 2     2018-04-25 16:55:34 2018-04-25 09:05:22         5.177
# 3     2018-04-25 16:03:12 2018-04-25 10:40:30        10.119
# 4     2018-04-25 18:17:30 2018-04-25 09:18:28         7.910
# ...                   ...                 ...           ...
# 28179 2021-09-13 18:34:43 2021-09-13 17:28:06        16.370
# 28180 2021-09-13 15:33:34 2021-09-13 13:56:33         2.902
# 28181 2021-09-13 17:25:36 2021-09-13 14:41:31         2.285
# 28182 2021-09-13 18:01:49 2021-09-13 16:18:07         6.715
# 28183 2021-09-13 18:43:11 2021-09-13 17:13:35         2.018
#
#                                     sessionID  siteID  stationID  \
# 0       2_39_95_27_2018-04-25 13:45:09.617470       2       9527
# 1      2_39_79_380_2018-04-25 13:45:49.962001       2      79380
# 2      2_39_79_379_2018-04-25 14:37:06.460772       2      79379
# 3      2_39_79_381_2018-04-25 14:40:33.638896       2      79381
# 4      2_39_139_28_2018-04-25 14:43:49.647430       2      13928
# ...                                       ...     ...        ...
# 28179  2_39_130_31_2021-09-13 19:43:01.675072       2      13031
# 28180  2_39_91_437_2021-09-13 19:53:30.351099       2      91437
# 28181   2_39_89_25_2021-09-13 21:12:53.318460       2       8925
# 28182  2_39_123_23_2021-09-13 21:16:44.026068       2      12323
# 28183  2_39_91_437_2021-09-13 23:10:59.528292       2      91437
#
#          futility_time
# 0      0 days 08:12:01
# 1      0 days 08:13:01
# 2      0 days 07:50:12
# 3      0 days 05:22:42
# 4      0 days 08:59:02
# ...                ...
# 28179  0 days 01:06:37
# 28180  0 days 01:37:01
# 28181  0 days 02:44:05
# 28182  0 days 01:43:42
# 28183  0 days 01:29:36
#
# [28184 rows x 10 columns]

# %% [markdown]
# # Create some features and remove anomalies

# %% [markdown]
# **Create 2 new features namely `total_charging_time` = `doneChargingTime` - `ConnecttionTime` and `idle_time` = `disconnectionTime` - `doneChargingTime`**

# %%
caltech_dataframe['total_charging_time'] = (caltech_dataframe['doneChargingTime'] - caltech_dataframe['connectionTime']).dt.total_seconds()
caltech_dataframe['idle_time'] = (caltech_dataframe['disconnectTime'] - caltech_dataframe['doneChargingTime']).dt.total_seconds()

# %%
caltech_dataframe['total_charging_time'] = caltech_dataframe['total_charging_time'].apply(lambda x: x / 3600)
caltech_dataframe['idle_time'] = caltech_dataframe['idle_time'].apply(lambda x: x / 3600)

# %% [markdown]
# **Filtering out the dataframe by selecting only the rows where the value in the `doneChargingTime` column is greater than or equal to the value in the `connectionTime` column. `connectionTime` > `doneChargingTime` -----> anomaly**

# %%
mask = caltech_dataframe['doneChargingTime'] >= caltech_dataframe['connectionTime']
caltech_dataframe = caltech_dataframe.loc[mask].reset_index(drop=True)

# %%
caltech_dataframe
# Out:
#                             _id  clusterID      connectionTime  \
# 0      5bc90cb9f9af8b0d7fe77cd3         39 2018-04-25 06:45:10
# 1      5bc90cb9f9af8b0d7fe77cd4         39 2018-04-25 06:45:50
# 2      5bc90cb9f9af8b0d7fe77cd5         39 2018-04-25 07:37:06
# 3      5bc90cb9f9af8b0d7fe77cd6         39 2018-04-25 07:40:34
# 4      5bc90cb9f9af8b0d7fe77cd7         39 2018-04-25 07:43:50
# ...                         ...        ...                 ...
# 28153  61550519f9af8b76960e1697         39 2021-09-13 12:43:16
# 28154  61550519f9af8b76960e1698         39 2021-09-13 12:53:30
# 28155  61550519f9af8b76960e169a         39 2021-09-13 14:12:53
# 28156  61550519f9af8b76960e169b         39 2021-09-13 14:17:04
# 28157  61550519f9af8b76960e169d         39 2021-09-13 16:11:12
#
#            disconnectTime    doneChargingTime  kWhDelivered  \
# 0     2018-04-25 17:56:16 2018-04-25 09:44:15        10.013
# 1     2018-04-25 16:04:45 2018-04-25 07:51:44         5.257
# 2     2018-04-25 16:55:34 2018-04-25 09:05:22         5.177
# 3     2018-04-25 16:03:12 2018-04-25 10:40:30        10.119
# 4     2018-04-25 18:17:30 2018-04-25 09:18:28         7.910
# ...                   ...                 ...           ...
# 28153 2021-09-13 18:34:43 2021-09-13 17:28:06        16.370
# 28154 2021-09-13 15:33:34 2021-09-13 13:56:33         2.902
# 28155 2021-09-13 17:25:36 2021-09-13 14:41:31         2.285
# 28156 2021-09-13 18:01:49 2021-09-13 16:18:07         6.715
# 28157 2021-09-13 18:43:11 2021-09-13 17:13:35         2.018
#
#                                     sessionID  siteID  stationID  \
# 0       2_39_95_27_2018-04-25 13:45:09.617470       2       9527
# 1      2_39_79_380_2018-04-25 13:45:49.962001       2      79380
# 2      2_39_79_379_2018-04-25 14:37:06.460772       2      79379
# 3      2_39_79_381_2018-04-25 14:40:33.638896       2      79381
# 4      2_39_139_28_2018-04-25 14:43:49.647430       2      13928
# ...                                       ...     ...        ...
# 28153  2_39_130_31_2021-09-13 19:43:01.675072       2      13031
# 28154  2_39_91_437_2021-09-13 19:53:30.351099       2      91437
# 28155   2_39_89_25_2021-09-13 21:12:53.318460       2       8925
# 28156  2_39_123_23_2021-09-13 21:16:44.026068       2      12323
# 28157  2_39_91_437_2021-09-13 23:10:59.528292       2      91437
#
#          futility_time  total_charging_time  idle_time
# 0      0 days 08:12:01             2.984722   8.200278
# 1      0 days 08:13:01             1.098333   8.216944
# 2      0 days 07:50:12             1.471111   7.836667
# 3      0 days 05:22:42             2.998889   5.378333
# 4      0 days 08:59:02             1.577222   8.983889
# ...                ...                  ...        ...
# 28153  0 days 01:06:37             4.747222   1.110278
# 28154  0 days 01:37:01             1.050833   1.616944
# 28155  0 days 02:44:05             0.477222   2.734722
# 28156  0 days 01:43:42             2.017500   1.728333
# 28157  0 days 01:29:36             1.039722   1.493333
#
# [28158 rows x 12 columns]

# %% [markdown]
# **Checking if the value in the `doneChargingTime` column is greater than or equal to the corresponding value in the `disconnectTime` column. `doneChargingTime` > `disconnectTime` -----> anomaly**

# %%
mask1 = caltech_dataframe[caltech_dataframe['doneChargingTime'] >= caltech_dataframe['disconnectTime']]
len(mask1)
# Out:
# 0

# %% [markdown]
# # Dropping some unnecessary columns

# %% [markdown]
# **Dropping some unnecessary columns `clusterID`, `_id`, `sessionID`, `disconnectTime`, `doneChargingTime`, `futility_time`**

# %%
def dropping_unnecessary_columns(dataframe):
  columns_tobe_dropped = ['clusterID', '_id', 'sessionID', 'disconnectTime', 'doneChargingTime', 'futility_time']

  for column in columns_tobe_dropped:
    dataframe.drop([column], axis=1, inplace=True)

  return dataframe

# %%
caltech_dataframe =dropping_unnecessary_columns(caltech_dataframe)
caltech_dataframe.sort_values(by='connectionTime')
caltech_dataframe.head()
# Out:
#        connectionTime  kWhDelivered  siteID  stationID  total_charging_time  \
# 0 2018-04-25 06:45:10        10.013       2       9527             2.984722
# 1 2018-04-25 06:45:50         5.257       2      79380             1.098333
# 2 2018-04-25 07:37:06         5.177       2      79379             1.471111
# 3 2018-04-25 07:40:34        10.119       2      79381             2.998889
# 4 2018-04-25 07:43:50         7.910       2      13928             1.577222
#
#    idle_time
# 0   8.200278
# 1   8.216944
# 2   7.836667
# 3   5.378333
# 4   8.983889

# %% [markdown]
# **Exploring some statistics**

# %%
caltech_max_energy =  caltech_dataframe.describe()['kWhDelivered']['max']
caltech_min_energy =  caltech_dataframe.describe()['kWhDelivered']['min']
caltech_max_charging_time =  caltech_dataframe.describe()['total_charging_time']['max']
caltech_min_charging_time =  caltech_dataframe.describe()['total_charging_time']['min']
caltech_max_idle_time =  caltech_dataframe.describe()['idle_time']['max']
caltech_min_idle_time =  caltech_dataframe.describe()['idle_time']['min']


# Print the maximum and minimum values
print("Office Maximum and Minimum Values:")
print("-------------------------------")
print(f"Max kWhDelivered:           {caltech_max_energy:.3f}")
print(f"Min kWhDelivered:           {caltech_min_energy:.1f}")
print(f"Max total_charging_time:    {caltech_max_charging_time:.6f}")
print(f"Min total_charging_time:    {caltech_min_charging_time:.1f}")
print(f"Max idle_time:              {caltech_max_idle_time:.6f}")
print(f"Min idle_time:              {caltech_min_idle_time:.1f}")
# Out:
# Office Maximum and Minimum Values:
# -------------------------------
# Max kWhDelivered:           75.528
# Min kWhDelivered:           0.5
# Max total_charging_time:    200.015833
# Min total_charging_time:    0.0
# Max idle_time:              156.121389
# Min idle_time:              0.0

# %% [markdown]
# **Deleting the rows where total_charging_time = 0 but kWhDelivered is not != 0**

# %%
# Select the rows where total_charging_time is 0 but kWhDelivered is not equal to 0
condition = (caltech_dataframe['total_charging_time'] == 0) & (caltech_dataframe['kWhDelivered'] != 0)

# Drop the selected rows from the dataframe
caltech_dataframe = caltech_dataframe.drop(caltech_dataframe[condition].index)

# %%
caltech_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28156 entries, 0 to 28157
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   connectionTime       28156 non-null  datetime64[ns]
#  1   kWhDelivered         28156 non-null  float64
#  2   siteID               28156 non-null  int64
#  3   stationID            28156 non-null  int64
#  4   total_charging_time  28156 non-null  float64
#  5   idle_time            28156 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2)
# memory usage: 1.5 MB

# %%
caltech_dataframe.describe()
# Out:
#        kWhDelivered   siteID      stationID  total_charging_time     idle_time
# count  28156.000000  28156.0   28156.000000         28156.000000  28156.000000
# mean       8.818767      2.0   51556.764349             2.884159      2.984427
# std        8.124610      0.0   38764.893253             3.233148      4.914115
# min        0.501000      2.0    8824.000000             0.000833      0.000278
# 25%        3.388750      2.0   12818.000000             1.164444      0.003889
# 50%        6.579000      2.0   78361.000000             2.022361      1.325556
# 75%       12.377750      2.0   79381.000000             3.753125      4.988681
# max       75.528000      2.0  139567.000000           200.015833    156.121389

# %% [markdown]
# # Some more anomalies removal

# %%
x = caltech_dataframe['kWhDelivered']
percentiles = [20, 30, 40]
for p in percentiles:
    percentile = stats.percentileofscore(x, p)
    print(f"{p} kWh is in the {percentile:.2f} percentile")
# Out:
# 20 kWh is in the 93.47 percentile
# 30 kWh is in the 96.90 percentile
# 40 kWh is in the 98.63 percentile

# %%
plt.figure(figsize=(25, 5))
plt.hist(caltech_dataframe['kWhDelivered'], bins=50)
plt.xlabel('KWh Delivered')
plt.ylabel('Count')
plt.title('Distribution of KWh Delivered')
plt.show()

# %%
fig = px.histogram(caltech_dataframe, x='kWhDelivered', nbins=50)
fig.update_layout(
    xaxis_title='KWh Delivered',
    yaxis_title='Count',
    title='Distribution of KWh Delivered'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="
198,4.995,9.043,4.994,16.008,13.422,2.031,3.145,9.664,3.86,11.344,4.801,1.58,30.8,7.711,6.254,4.448,4.157,39.911,15.958,4.822,9.454,3.671,9.251,9.259,13.854,2.258,12.398,8.869,10.684,6.687,0.756,11.656,13.503,7.508,17.011,7.212,13.216,8.884,13.173,4.657,3.469,11.46,5.822,7.489,7.212,4.946,3.289,2.638,5.434,0.58,12.818,0.807,4.956,2.128,3.723,11.489,2.892,4.257,2.138,7.73,22.087,8.7,7.493,4.763,14.11,12.406,2.034,5.949,7.496,1.45,10.153,6.912,6.689,10.286,12.674,4.724,12.982,0.535,3.573,6.999,0.886,15.659,13.917,0.661,12.014,3.356,10.121,2.954,10.211,7.978,6.577,6.156,4.684,14.019,11.609,2.98,1.511,4.177,2.73,9.845,21.839,14.034,4.048,14.928,3.561,8.478,8.321,13.948,9.981,3.173,5.245,13.946,16.157,8.714,5.19,8.316,25.556,16.328,7.515,4.657,7.305,8.212,35.982,2.657,1.212,4.806,11.539,2.588,6.044,7.637,6.94,9.183,2.473,14.889,4.753,3.23,6.279,6.592,4.823,7.01,18.703,2.568,3.774,28.545,13.922,13.917,13.796,13.72,5.428,2.835,39.878,16.507,39.842,1.112,6.607,17.111,23.716,4.493,3.74,4.01,13.912,15.022,3.847,6.94,5.982,21.967,1.344,12.381,3.599,37.49,33.013,15.737,13.91,2.14,10.737,5.884,7.102,6.983, ...

# %%
x = caltech_dataframe['total_charging_time']
percentiles = [8, 9, 10]
for p in percentiles:
    percentile = stats.percentileofscore(x, p)
    print(f"{p} Hour Charging Time is in the {percentile:.2f} percentile")
# Out:
# 8 Hour Charging Time is in the 94.70 percentile
# 9 Hour Charging Time is in the 97.04 percentile
# 10 Hour Charging Time is in the 98.54 percentile

# %%
plt.figure(figsize=(25, 5))
plt.hist(caltech_dataframe['total_charging_time'], bins=50)
plt.xlabel('Total Charging Time')
plt.ylabel('Count')
plt.title('Distribution of Total Charging Time')
plt.show()

# %%
fig = px.histogram(caltech_dataframe, x='total_charging_time', nbins=50)
fig.update_layout(
    xaxis_title='Total Charging Time',
    yaxis_title='Count',
    title='Distribution of Total Charging Time'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fdd20c7a-811b-4998-b296-94f5ccc82901" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fdd20c7a-811b-4998-b296-94f5ccc82901")) {                    Plotly.newPlot(                        "fdd20c7a-811b-4998-b296-94f5ccc82901",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"total_charging_time=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":50,"offsetgroup":"","orientation":"v","showlegend":false,"x":[2.984722222222222,1.0983333333333334,1.471111111111111,2.9988888888888887,1.5772222222222223,3.6666666666666665,1.8344444444444445,0.9511111111111111,3.3205555555555555,1.0583333333333333,1.4530555555555555,0.7791666666666667,3.4072222222222224,2.9208333333333334,2.2669444444444444,1.9241666666666666,2.2952777777777778,2.0919444444444446,4.029444444444445,2.428611111111111,2.4627777777777777,8.213888888888889,1.2061111111111111,3.4280555555555554,6.266388888888889,2.1458333333333335,6.080555555555556,2.1694444444444443,4.814444444444445,2.254166666666667,7.318611111111111,0.8219444444444445,0.8825,2.452777777777778,3.506666666666667,5.217777777777778,3.222777777777778,0.5841666666666666,
# %%
caltech_dataframe_before_COVID = caltech_dataframe.loc[caltech_dataframe['connectionTime'] < pd.to_datetime('2020-03-15')]
caltech_dataframe_before_COVID.shape
# Out:
# (26012, 6)

# %% [markdown]
# **Removing Some outliers where kWhDelivered > 40, total_charging_time > 10 and idle_time > 12**

# %%
caltech_dataframe_before_COVID = caltech_dataframe_before_COVID[caltech_dataframe_before_COVID['kWhDelivered'] <= 40].reset_index(drop=True)
caltech_dataframe_before_COVID = caltech_dataframe_before_COVID[caltech_dataframe_before_COVID['total_charging_time'] <= 10].reset_index(drop=True)
caltech_dataframe_before_COVID = caltech_dataframe_before_COVID[caltech_dataframe_before_COVID['idle_time'] <= 12].reset_index(drop=True)
caltech_dataframe_before_COVID
# Out:
#            connectionTime  kWhDelivered  siteID  stationID  \
# 0     2018-04-25 06:45:10        10.013       2       9527
# 1     2018-04-25 06:45:50         5.257       2      79380
# 2     2018-04-25 07:37:06         5.177       2      79379
# 3     2018-04-25 07:40:34        10.119       2      79381
# 4     2018-04-25 07:43:50         7.910       2      13928
# ...                   ...           ...     ...        ...
# 24859 2020-03-13 20:29:15         3.493       2      12521
# 24860 2020-03-14 15:10:09         4.421       2      12719
# 24861 2020-03-14 16:26:22         0.830       2      13130
# 24862 2020-03-14 17:57:31         3.868       2      12917
# 24863 2020-03-14 22:58:50        29.647       2      90440
#
#        total_charging_time  idle_time
# 0                 2.984722   8.200278
# 1                 1.098333   8.216944
# 2                 1.471111   7.836667
# 3                 2.998889   5.378333
# 4                 1.577222   8.983889
# ...                    ...        ...
# 24859             1.015556   0.001389
# 24860             1.493889   0.393056
# 24861             0.504444   1.075278
# 24862             1.113056   0.001389
# 24863             4.435556   7.880833
#
# [24864 rows x 6 columns]

# %% [markdown]
# # Addressing duplicacy in `connectionTime`

# %% [markdown]
# **Checking how many duplicates are there for the same `connectionTime`**

# %%
# Find the duplicated rows based on the 'connectionTime' column
duplicated_df = caltech_dataframe_before_COVID[caltech_dataframe_before_COVID.duplicated(subset=['connectionTime'], keep=False)]

# Print the new DataFrame
duplicated_df
# Out:
#            connectionTime  kWhDelivered  siteID  stationID  \
# 538   2018-05-07 13:47:50         2.536       2     123557
# 539   2018-05-07 13:47:50        14.295       2      95444
# 540   2018-05-07 13:47:50         1.585       2      12719
# 1009  2018-05-16 09:26:36         1.990       2     129563
# 1010  2018-05-16 09:26:36         2.772       2      78365
# 3281  2018-06-26 08:44:15        12.094       2      12521
# 3282  2018-06-26 08:44:15        21.117       2      90440
# 6019  2018-08-09 20:13:41        11.344       2      12818
# 6020  2018-08-09 20:13:41         5.958       2      12620
# 7273  2018-08-28 08:54:35         5.064       2      78365
# 7274  2018-08-28 08:54:35         3.036       2      78361
# 7275  2018-08-28 08:54:35         3.615       2      78363
# 7276  2018-08-28 08:54:35        13.848       2      12521
# 7277  2018-08-28 08:54:35         4.804       2      13928
# 7360              2.543333   5.190000
# 7361              5.003611   3.420833
# 7362              2.715833   0.001111
# 7363              5.060556   3.309444
# 7364              2.174167   4.868056
# 7365              4.296111   0.002500
# 8841              3.176389   0.972222
# 8842              1.294722   0.000833
# 8843              1.334167   7.168056
# 8876              1.571667   0.002222
# 8877              0.868889   1.078333
# 11114             3.196111   5.636389
# 11115             2.043333   7.466667
# 11607             2.024444   8.055556
# 11608             3.214722   1.009722
# 12200             3.011111   4.829722
# 12201             2.910556   6.388611
# 14399             0.657778   0.001111
# 14400             1.606944   6.424444
# 16356             7.571389   0.001944
# 16357             1.495000   2.299167
# 17809             1.650833   0.001389
# 17810             2.022778   5.447222
# 18534             6.298333   1.823056
# 18535             1.950556   5.396667
# 18625             2.112500   0.001667
# 18626             0.513333   9.935000
# 20981             3.472500   1.820000
# 20982             0.406111   8.871111
# 24755             0.358611   0.001389
# 24756             8.730000   0.591111

# %% [markdown]
# **50 duplicates. We need to handle them**

# %%
len(duplicated_df)
# Out:
# 56

# %%
caltech_dataframe_before_COVID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24864 entries, 0 to 24863
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   connectionTime       24864 non-null  datetime64[ns]
#  1   kWhDelivered         24864 non-null  float64
#  2   siteID               24864 non-null  int64
#  3   stationID            24864 non-null  int64
#  4   total_charging_time  24864 non-null  float64
#  5   idle_time            24864 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2)
# memory usage: 1.1 MB

# %% [markdown]
# **The unique hours that we have duplicacy**

# %%
unique_hours = duplicated_df['connectionTime'].dt.hour.unique()
unique_hours
# Out:
# array([13,  9,  8, 20, 18, 10, 12])

# %% [markdown]
# **At the given duplicate hours we are finding out the maximum occuring `stationID`for the whole time period.**

# %%
df = caltech_dataframe_before_COVID.copy()
# First, make sure the connectionTime column is a datetime type
df['connectionTime'] = pd.to_datetime(df['connectionTime'])

# Extract the hour from the connectionTime column
df['hour'] = df['connectionTime'].dt.hour

# Then, filter the DataFrame to only include rows with the hours of interest
df_filtered = df[df['hour'].isin(unique_hours)]

# Group the filtered DataFrame by hour and stationID, and count the occurrences of each
grouped = df_filtered.groupby(['hour', 'stationID']).size()

# Get the stationID with the highest count for each hour of interest
for hour in unique_hours:
    max_station = grouped[hour].idxmax()
    print(f"At hour {hour}, stationID {max_station} had the highest count.")
# Out:
# At hour 13, stationID 13928 had the highest count.
# At hour 9, stationID 8925 had the highest count.
# At hour 8, stationID 13130 had the highest count.
# At hour 20, stationID 13928 had the highest count.
# At hour 18, stationID 13928 had the highest count.
# At hour 10, stationID 12422 had the highest count.
# At hour 12, stationID 8824 had the highest count.

# %% [markdown]
# **Also sorting the occurance of `stationID` from highest to lowest for a particular hour (obviously duplicated unique hours)**

# %%
unique_hours = duplicated_df['connectionTime'].dt.hour.unique()

df = caltech_dataframe_before_COVID.copy()
df['connectionTime'] = pd.to_datetime(df['connectionTime'])
df['hour'] = df['connectionTime'].dt.hour
df_filtered = df[df['hour'].isin(unique_hours)]

grouped = df_filtered.groupby(['hour', 'stationID']).size().reset_index(name='count')

for hour in unique_hours:
    hour_df = grouped[grouped['hour'] == hour].sort_values('count', ascending=False)
    print(f"At hour {hour}, the occurrences of stationID from highest to lowest are:")
    for index, row in hour_df.iterrows():
        print(f"{row['stationID']}: {row['count']} occurrences")
# Out:
# At hour 13, the occurrences of stationID from highest to lowest are:
# 13928: 54 occurrences
# 79383: 53 occurrences
# 8824: 49 occurrences
# 91441: 46 occurrences
# 12323: 44 occurrences
# 12521: 44 occurrences
# 12422: 43 occurrences
# 78361: 42 occurrences
# 78367: 40 occurrences
# 78364: 39 occurrences
# 13130: 39 occurrences
# 88438: 38 occurrences
# 12719: 38 occurrences
# 12917: 38 occurrences
# 78360: 37 occurrences
# 13829: 37 occurrences
# 13031: 37 occurrences
# 92436: 36 occurrences
# 79377: 35 occurrences
# 78366: 34 occurrences
# 79378: 34 occurrences
# 92442: 33 occurrences
# 9026: 32 occurrences
# 78363: 32 occurrences
# 12818: 32 occurrences
# 78365: 30 occurrences
# 91437: 30 occurrences
# 9527: 30 occurrences
# 79380: 27 occurrences
# 79381: 26 occurrences
# 12620: 25 occurrences
# 8925: 24 occurrences
# 79376: 23 occurrences
# 95444: 22 occurrences
# 79379: 21 occurrences
# 79382: 21 occurrences
# 123557: 20 occurrences
# 89439: 19 occurrences
# 90440: 18 occurrences
# 83387: 12 occurrences
# 138566: 11 occurrences
# 130564: 9 occurrences
# 139567: 9 occurrences
# 125559: 8 occurrences
# 83386: 7 occurrences
# 124558: 5 occurrences
# 126560: 5 occurrences
# 131565: 5 occurrences
# 127561: 3 occurrences
# 128562: 2 occurrences
# 129563: 2 occurrences
# 82385: 2 occurrences
# 82384: 1 occurrences
# At hour 9, the occurrences of stationID from highest to lowest are:
# 8925: 226 occurrences
# 12323: 174 occurrences
# 91437: 144 occurrences
# 78365: 140 occurrences
# 9026: 133 occurrences
# 12422: 132 occurrences
# 9527: 124 occurrences
# 89439: 123 occurrences
# 92436: 122 occurrences
# 90440: 119 occurrences
# 12521: 115 occurrences
# 12719: 108 occurrences
# 79376: 106 occurrences
# 12917: 105 occurrences
# 92442: 98 occurrences
# 78363: 94 occurrences
# 88438: 92 occurrences
# 95444: 91 occurrences
# 78361: 89 occurrences
# 79380: 86 occurrences
# 78364: 81 occurrences
# 79377: 81 occurrences
# 78360: 80 occurrences
# 79381: 80 occurrences
# 79379: 79 occurrences
# 8824: 79 occurrences
# 79378: 79 occurrences
# 12620: 76 occurrences
# 78367: 74 occurrences
# 12818: 70 occurrences
# 91441: 69 occurrences
# 78366: 64 occurrences
# 79382: 63 occurrences
# 123557: 62 occurrences
# 13928: 61 occurrences
# 79383: 56 occurrences
# 128562: 51 occurrences
# 13130: 49 occurrences
# 13031: 49 occurrences
# 130564: 42 occurrences
# 13829: 40 occurrences
# 83386: 39 occurrences
# 126560: 36 occurrences
# 127561: 33 occurrences
# 129563: 30 occurrences
# 139567: 29 occurrences
# 124558: 29 occurrences
# 131565: 28 occurrences
# 125559: 25 occurrences
# 138566: 24 occurrences
# 83387: 7 occurrences
# 82385: 1 occurrences
# At hour 8, the occurrences of stationID from highest to lowest are:
# 13130: 258 occurrences
# 13928: 215 occurrences
# 8925: 195 occurrences
# 79379: 190 occurrences
# 78366: 178 occurrences
# 79377: 174 occurrences
# 91437: 169 occurrences
# 12917: 151 occurrences
# 12719: 141 occurrences
# 79380: 140 occurrences
# 79383: 137 occurrences
# 79382: 131 occurrences
# 79381: 130 occurrences
# 79378: 126 occurrences
# 78361: 125 occurrences
# 13829: 122 occurrences
# 92442: 121 occurrences
# 78365: 117 occurrences
# 78360: 112 occurrences
# 78367: 112 occurrences
# 12521: 112 occurrences
# 12323: 112 occurrences
# 78363: 111 occurrences
# 79376: 107 occurrences
# 13031: 104 occurrences
# 78364: 100 occurrences
# 9527: 92 occurrences
# 9026: 92 occurrences
# 8824: 88 occurrences
# 92436: 83 occurrences
# 95444: 78 occurrences
# 124558: 65 occurrences
# 88438: 64 occurrences
# 90440: 62 occurrences
# 12818: 61 occurrences
# 12620: 56 occurrences
# 91441: 51 occurrences
# 12422: 49 occurrences
# 89439: 48 occurrences
# 123557: 35 occurrences
# 126560: 30 occurrences
# 83386: 25 occurrences
# 138566: 12 occurrences
# 128562: 9 occurrences
# 130564: 9 occurrences
# 139567: 8 occurrences
# 125559: 7 occurrences
# 127561: 4 occurrences
# 83387: 3 occurrences
# 129563: 3 occurrences
# 131565: 3 occurrences
# At hour 20, the occurrences of stationID from highest to lowest are:
# 13928: 84 occurrences
# 13130: 53 occurrences
# 13829: 48 occurrences
# 79378: 38 occurrences
# 13031: 34 occurrences
# 12719: 33 occurrences
# 12917: 31 occurrences
# 79379: 31 occurrences
# 12521: 27 occurrences
# 12818: 27 occurrences
# 8925: 19 occurrences
# 12422: 17 occurrences
# 9527: 17 occurrences
# 12620: 15 occurrences
# 12323: 15 occurrences
# 91437: 14 occurrences
# 79377: 14 occurrences
# 8824: 13 occurrences
# 79380: 13 occurrences
# 78365: 12 occurrences
# 79376: 11 occurrences
# 78360: 8 occurrences
# 79382: 8 occurrences
# 78366: 8 occurrences
# 78361: 6 occurrences
# 95444: 6 occurrences
# 78364: 5 occurrences
# 128562: 5 occurrences
# 79383: 5 occurrences
# 79381: 4 occurrences
# 90440: 3 occurrences
# 92436: 3 occurrences
# 126560: 3 occurrences
# 123557: 3 occurrences
# 92442: 3 occurrences
# 138566: 3 occurrences
# 83386: 3 occurrences
# 125559: 2 occurrences
# 78363: 2 occurrences
# 78367: 2 occurrences
# 9026: 1 occurrences
# 89439: 1 occurrences
# 83387: 1 occurrences
# 124558: 1 occurrences
# 130564: 1 occurrences
# At hour 18, the occurrences of stationID from highest to lowest are:
# 13928: 182 occurrences
# 13130: 121 occurrences
# 13829: 111 occurrences
# 12917: 91 occurrences
# 12719: 77 occurrences
# 13031: 67 occurrences
# 12521: 58 occurrences
# 12818: 51 occurrences
# 12323: 39 occurrences
# 12620: 34 occurrences
# 91437: 28 occurrences
# 9527: 27 occurrences
# 8925: 25 occurrences
# 79377: 24 occurrences
# 12422: 21 occurrences
# 8824: 20 occurrences
# 79379: 19 occurrences
# 79378: 15 occurrences
# 78365: 15 occurrences
# 79381: 14 occurrences
# 9026: 13 occurrences
# 78366: 12 occurrences
# 79380: 12 occurrences
# 78360: 11 occurrences
# 78367: 10 occurrences
# 79383: 8 occurrences
# 83387: 7 occurrences
# 92436: 7 occurrences
# 78363: 7 occurrences
# 92442: 6 occurrences
# 123557: 6 occurrences
# 79382: 6 occurrences
# 83386: 6 occurrences
# 90440: 5 occurrences
# 89439: 5 occurrences
# 78361: 5 occurrences
# 79376: 5 occurrences
# 95444: 3 occurrences
# 124558: 3 occurrences
# 131565: 3 occurrences
# 78364: 2 occurrences
# 125559: 2 occurrences
# 126560: 2 occurrences
# 127561: 2 occurrences
# 128562: 2 occurrences
# 138566: 2 occurrences
# 91441: 1 occurrences
# 88438: 1 occurrences
# 129563: 1 occurrences
# 130564: 1 occurrences
# At hour 10, the occurrences of stationID from highest to lowest are:
# 12422: 99 occurrences
# 92436: 88 occurrences
# 78363: 83 occurrences
# 9527: 83 occurrences
# 9026: 80 occurrences
# 91441: 75 occurrences
# 90440: 70 occurrences
# 79378: 69 occurrences
# 79376: 69 occurrences
# 95444: 69 occurrences
# 78360: 69 occurrences
# 78364: 67 occurrences
# 8824: 66 occurrences
# 91437: 62 occurrences
# 12323: 62 occurrences
# 78365: 62 occurrences
# 92442: 62 occurrences
# 78361: 60 occurrences
# 88438: 51 occurrences
# 13130: 48 occurrences
# 79377: 46 occurrences
# 123557: 46 occurrences
# 8925: 43 occurrences
# 79380: 43 occurrences
# 13928: 42 occurrences
# 12917: 42 occurrences
# 12719: 42 occurrences
# 89439: 42 occurrences
# 79383: 40 occurrences
# 78366: 39 occurrences
# 78367: 39 occurrences
# 12521: 37 occurrences
# 131565: 36 occurrences
# 79379: 36 occurrences
# 79381: 35 occurrences
# 13031: 35 occurrences
# 12620: 34 occurrences
# 79382: 30 occurrences
# 12818: 27 occurrences
# 138566: 26 occurrences
# 13829: 26 occurrences
# 130564: 26 occurrences
# 83386: 24 occurrences
# 127561: 20 occurrences
# 129563: 19 occurrences
# 128562: 19 occurrences
# 139567: 15 occurrences
# 126560: 13 occurrences
# 83387: 8 occurrences
# 125559: 5 occurrences
# 124558: 4 occurrences
# 78362: 1 occurrences
# 82384: 1 occurrences
# At hour 12, the occurrences of stationID from highest to lowest are:
# 8824: 73 occurrences
# 13928: 58 occurrences
# 13130: 55 occurrences
# 79377: 54 occurrences
# 78363: 54 occurrences
# 78365: 48 occurrences
# 12917: 44 occurrences
# 79380: 43 occurrences
# 78367: 42 occurrences
# 91441: 41 occurrences
# 78360: 40 occurrences
# 12323: 40 occurrences
# 78361: 40 occurrences
# 9026: 39 occurrences
# 12620: 38 occurrences
# 12818: 38 occurrences
# 13031: 38 occurrences
# 12719: 37 occurrences
# 12422: 36 occurrences
# 79378: 35 occurrences
# 90440: 35 occurrences
# 9527: 33 occurrences
# 12521: 33 occurrences
# 13829: 33 occurrences
# 8925: 33 occurrences
# 92436: 32 occurrences
# 91437: 31 occurrences
# 79379: 30 occurrences
# 95444: 30 occurrences
# 78366: 29 occurrences
# 78364: 29 occurrences
# 79381: 28 occurrences
# 79376: 27 occurrences
# 92442: 27 occurrences
# 79383: 22 occurrences
# 123557: 19 occurrences
# 88438: 18 occurrences
# 79382: 15 occurrences
# 89439: 15 occurrences
# 139567: 8 occurrences
# 83386: 8 occurrences
# 127561: 7 occurrences
# 126560: 6 occurrences
# 128562: 6 occurrences
# 130564: 6 occurrences
# 131565: 5 occurrences
# 129563: 4 occurrences
# 83387: 3 occurrences
# 138566: 3 occurrences
# 125559: 2 occurrences
# 82385: 1 occurrences
# 82384: 1 occurrences

# %% [markdown]
# **The duplicates for stationID at the same time are handled by selecting the stationID with the highest count for each hour (if available). If no such stationID is found, random rows are selected to ensure a minimum number of samples (n_samples) for that hour.**

# %%
n_samples = 1
# First, extract the hour from the connectionTime column
duplicated_df = duplicated_df.assign(hour=duplicated_df['connectionTime'].dt.hour)

# Filter the DataFrame to only include rows with the hours of interest
df_filtered = duplicated_df[duplicated_df['hour'].isin(unique_hours)]

# For each hour of interest, identify the stationID with the highest count and keep only the rows with that stationID
for hour in unique_hours:
    # Filter the DataFrame to only include rows for the current hour
    df_hour = df_filtered[df_filtered['hour'] == hour]
    # Group the DataFrame by stationID and count the occurrences of each
    grouped = df_hour.groupby('stationID').size().reset_index(name='count')
    # Sort the DataFrame by count in descending order
    grouped.sort_values('count', ascending=False, inplace=True)

    # Find the stationID with the highest count that is not already selected for this hour
    selected_stationID = None
    for stationID in grouped['stationID']:
        if not df_filtered[(df_filtered['hour'] == hour) & (df_filtered['stationID'] == stationID)].empty:
            selected_stationID = stationID
            break

    if selected_stationID is None:
        # If no stationID is found, pick random rows from the duplicated_df for this hour
        df_selected = df_filtered[df_filtered['hour'] == hour].sample(n=min(n_samples, len(df_filtered[df_filtered['hour'] == hour])), random_state=SEED)
    else:
        # Keep only the rows with the selected stationID for this hour
        df_selected = df_filtered[(df_filtered['hour'] != hour) | (df_filtered['stationID'] == selected_stationID)]

    # Add the selected rows to the final DataFrame
    if hour == unique_hours[0]:
        df_final = df_selected
    else:
        df_final = pd.concat([df_final, df_selected])

# Finally, remove duplicates based on connectionTime
df_final.drop_duplicates(subset='connectionTime', inplace=True)
selected_rows = df_final[df_final['connectionTime'] == '2018-05-07 13:47:50']
selected_rows
# Out:
#          connectionTime  kWhDelivered  siteID  stationID  total_charging_time  \
# 540 2018-05-07 13:47:50         1.585       2      12719             1.027222
#
#      idle_time  hour
# 540   3.926667    13

# %%
df_final.shape
# Out:
# (20, 7)

# %%
caltech_dataframe_before_COVID.shape
# Out:
# (24864, 6)

# %%
selected_rows = caltech_dataframe_before_COVID[caltech_dataframe_before_COVID['connectionTime'] == '2018-05-07 13:47:50']
selected_rows
# Out:
#          connectionTime  kWhDelivered  siteID  stationID  total_charging_time  \
# 538 2018-05-07 13:47:50         2.536       2     123557             3.570833
# 539 2018-05-07 13:47:50        14.295       2      95444             4.042778
# 540 2018-05-07 13:47:50         1.585       2      12719             1.027222
#
#      idle_time
# 538  10.126667
# 539   0.001389
# 540   3.926667

# %%
# Drop all the duplicate rows based on the 'connectionTime' column from the original dataframe
caltech_dataframe_before_COVID.drop_duplicates(subset=['connectionTime'], keep=False, inplace=True)

# %%
caltech_dataframe_before_COVID.shape
# Out:
# (24808, 6)

# %%
selected_rows = caltech_dataframe_before_COVID[caltech_dataframe_before_COVID['connectionTime'] == '2018-05-07 13:47:50']
selected_rows
# Out:
# Empty DataFrame
# Columns: [connectionTime, kWhDelivered, siteID, stationID, total_charging_time, idle_time]
# Index: []

# %%
duplicates = caltech_dataframe_before_COVID.duplicated(subset='connectionTime')
if duplicates.any():
    print('There are duplicates based on the connectionTime column.')
else:
    print('There are no duplicates based on the connectionTime column.')
# Out:
# There are no duplicates based on the connectionTime column.

# %%
# Concatenate the selected_rows DataFrame to caltech_dataframe_before_COVID
caltech_dataframe_before_COVID = pd.concat([caltech_dataframe_before_COVID, df_final], ignore_index=True)
caltech_dataframe_before_COVID.shape
# Out:
# (24828, 7)

# %%
caltech_dataframe_before_COVID
# Out:
#            connectionTime  kWhDelivered  siteID  stationID  \
# 0     2018-04-25 06:45:10        10.013       2       9527
# 1     2018-04-25 06:45:50         5.257       2      79380
# 2     2018-04-25 07:37:06         5.177       2      79379
# 3     2018-04-25 07:40:34        10.119       2      79381
# 4     2018-04-25 07:43:50         7.910       2      13928
# ...                   ...           ...     ...        ...
# 24823 2019-05-14 09:56:27         6.511       2      78364
# 24824 2019-06-10 10:02:37         3.184       2      78365
# 24825 2019-06-12 12:05:04         3.467       2      79379
# 24826 2019-09-27 08:32:41        22.124       2      92442
# 24827 2020-03-09 08:09:22         0.572       2      79380
#
#        total_charging_time  idle_time  hour
# 0                 2.984722   8.200278   NaN
# 1                 1.098333   8.216944   NaN
# 2                 1.471111   7.836667   NaN
# 3                 2.998889   5.378333   NaN
# 4                 1.577222   8.983889   NaN
# ...                    ...        ...   ...
# 24823             1.650833   0.001389   9.0
# 24824             6.298333   1.823056  10.0
# 24825             2.112500   0.001667  12.0
# 24826             3.472500   1.820000   8.0
# 24827             0.358611   0.001389   8.0
#
# [24828 rows x 7 columns]

# %%
selected_rows = caltech_dataframe_before_COVID[caltech_dataframe_before_COVID['connectionTime'] == '2018-05-07 13:47:50']
selected_rows
# Out:
#            connectionTime  kWhDelivered  siteID  stationID  \
# 24808 2018-05-07 13:47:50         1.585       2      12719
#
#        total_charging_time  idle_time  hour
# 24808             1.027222   3.926667  13.0

# %%
# Drop the 'hour' column from the dataframe
caltech_dataframe_before_COVID.drop('hour', axis=1, inplace=True)

# %%
caltech_dataframe_before_COVID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24828 entries, 0 to 24827
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   connectionTime       24828 non-null  datetime64[ns]
#  1   kWhDelivered         24828 non-null  float64
#  2   siteID               24828 non-null  int64
#  3   stationID            24828 non-null  int64
#  4   total_charging_time  24828 non-null  float64
#  5   idle_time            24828 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2)
# memory usage: 1.1 MB

# %% [markdown]
# **Finally done! 😊**

# %%
duplicates = caltech_dataframe_before_COVID.duplicated(subset='connectionTime')
if duplicates.any():
    print('There are duplicates based on the connectionTime column.')
else:
    print('There are no duplicates based on the connectionTime column.')
# Out:
# There are no duplicates based on the connectionTime column.

# %% [markdown]
# # Isolation Forest - Anomaly detection

# %% [markdown]
# **Checked Isolation Forest. But seems not helpful that much! Still deciding to keep or not**

# %%
features = ['kWhDelivered', 'total_charging_time', 'idle_time']

model = IsolationForest(n_estimators=100, max_samples='auto', contamination=0.1, verbose = False, max_features=3, random_state=SEED)
model.fit(caltech_dataframe_before_COVID[features].values)
# Out:
# IsolationForest(contamination=0.1, max_features=3, random_state=42,
#                 verbose=False)

# %%
print(model.get_params())
# Out:
# {'bootstrap': False, 'contamination': 0.1, 'max_features': 3, 'max_samples': 'auto', 'n_estimators': 100, 'n_jobs': None, 'random_state': 42, 'verbose': False, 'warm_start': False}

# %%
caltech_dataframe_before_COVID['scores'] = model.decision_function(caltech_dataframe_before_COVID[features].values)
caltech_dataframe_before_COVID['anomaly'] = model.predict(caltech_dataframe_before_COVID[features].values)

# %%
anomaly=caltech_dataframe_before_COVID.loc[caltech_dataframe_before_COVID['anomaly']==-1]
anomaly_index=list(anomaly.index)
anomaly
# Out:
#            connectionTime  kWhDelivered  siteID  stationID  \
# 9     2018-04-25 08:14:41         3.249       2      91437
# 26    2018-04-25 09:25:51        32.708       2      88438
# 43    2018-04-25 18:21:28         1.020       2      78367
# 52    2018-04-25 20:13:44         6.503       2      79378
# 57    2018-04-26 06:54:17         7.108       2      79380
# ...                   ...           ...     ...        ...
# 24779 2020-03-12 09:48:56         3.627       2      12323
# 24782 2020-03-12 10:19:04         1.134       2      12719
# 24793 2020-03-13 08:34:24         1.473       2      79379
# 24807 2020-03-14 22:58:50        29.647       2      90440
# 24809 2018-05-16 09:26:36         1.990       2     129563
#
#        total_charging_time  idle_time    scores  anomaly
# 9                 1.058333  10.131111 -0.008416       -1
# 26                6.080556   0.001389 -0.078634       -1
# 43                7.975556   2.186944 -0.043050       -1
# 52                2.314167  11.253611 -0.026709       -1
# 57                9.215278   0.020000 -0.015469       -1
# ...                    ...        ...       ...      ...
# 24779             8.098889   0.311944 -0.014758       -1
# 24782             6.937500   0.939167 -0.015280       -1
# 24793             0.409722   9.308889 -0.028468       -1
# 24807             4.435556   7.880833 -0.115036       -1
# 24809             0.977222  10.766111 -0.026010       -1
#
# [2483 rows x 8 columns]

# %%
# Drop the rows with anomalies
caltech_dataframe_before_COVID = caltech_dataframe_before_COVID.loc[caltech_dataframe_before_COVID['anomaly'] != -1].copy()
# Drop the "anomaly" and "score" columns
caltech_dataframe_before_COVID.drop(columns=["anomaly", "scores"], inplace=True)

# %%
caltech_dataframe_before_COVID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22345 entries, 0 to 24827
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   connectionTime       22345 non-null  datetime64[ns]
#  1   kWhDelivered         22345 non-null  float64
#  2   siteID               22345 non-null  int64
#  3   stationID            22345 non-null  int64
#  4   total_charging_time  22345 non-null  float64
#  5   idle_time            22345 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2)
# memory usage: 1.2 MB

# %% [markdown]
# # Some visualization

# %% [markdown]
# **Some visualization. But not important!**

# %%
# First, make sure the connectionTime column is a datetime type
df['connectionTime'] = pd.to_datetime(df['connectionTime'])

# Extract the hour from the connectionTime column
df['hour'] = df['connectionTime'].dt.hour

# Then, filter the DataFrame to only include rows with the hours of interest
hours_of_interest = list(range(0, 24))
df_filtered = df[df['hour'].isin(hours_of_interest)]

# Group the filtered DataFrame by hour and stationID, and count the occurrences of each
grouped = df_filtered.groupby(['hour', 'stationID']).size().reset_index(name='count')

# Get the stationID with the highest count for each hour of interest
for hour in hours_of_interest:
    df_hour = grouped[grouped['hour'] == hour]
    max_station = df_hour.loc[df_hour['count'].idxmax(), 'stationID']
    max_count = df_hour['count'].max()
    print(f"At hour {hour}, stationID {max_station} had the highest count with {max_count} occurrences.")
# Out:
# At hour 0, stationID 79380 had the highest count with 16 occurrences.
# At hour 1, stationID 79380 had the highest count with 13 occurrences.
# At hour 2, stationID 78365 had the highest count with 5 occurrences.
# At hour 3, stationID 13928 had the highest count with 4 occurrences.
# At hour 4, stationID 79383 had the highest count with 74 occurrences.
# At hour 5, stationID 12719 had the highest count with 15 occurrences.
# At hour 6, stationID 8925 had the highest count with 111 occurrences.
# At hour 7, stationID 78366 had the highest count with 124 occurrences.
# At hour 8, stationID 13130 had the highest count with 258 occurrences.
# At hour 9, stationID 8925 had the highest count with 226 occurrences.
# At hour 10, stationID 12422 had the highest count with 99 occurrences.
# At hour 11, stationID 8824 had the highest count with 63 occurrences.
# At hour 12, stationID 8824 had the highest count with 73 occurrences.
# At hour 13, stationID 13928 had the highest count with 54 occurrences.
# At hour 14, stationID 13928 had the highest count with 42 occurrences.
# At hour 15, stationID 12719 had the highest count with 53 occurrences.
# At hour 16, stationID 12323 had the highest count with 57 occurrences.
# At hour 17, stationID 13928 had the highest count with 80 occurrences.
# At hour 18, stationID 13928 had the highest count with 182 occurrences.
# At hour 19, stationID 13928 had the highest count with 80 occurrences.
# At hour 20, stationID 13928 had the highest count with 84 occurrences.
# At hour 21, stationID 13928 had the highest count with 65 occurrences.
# At hour 22, stationID 13928 had the highest count with 30 occurrences.
# At hour 23, stationID 13928 had the highest count with 13 occurrences.

# %%
import matplotlib.pyplot as plt

# Group the filtered DataFrame by hour and stationID, and count the occurrences of each
grouped = df_filtered.groupby(['hour', 'stationID']).size().reset_index(name='count')

# Plot a histogram of the station occurrences at each hour
fig, ax = plt.subplots(figsize=(20, 20))
for name, group in grouped.groupby('stationID'):
    ax.bar(group['hour'], group['count'], label=name)

# Add labels and legend
ax.set_xlabel('Hour of Day')
ax.set_ylabel('Count of Occurrences')
ax.set_title('Station Occurrences at Each Hour')
ax.legend(title='Station ID')
plt.show()

# %% [markdown]
# # Save the preprocessed Dataframe

# %%
file_path = '../../../data/preprocessed/ACN/acn_caltech_0.2_0.1_with_stationID_22_06_2023.csv'
caltech_dataframe_before_COVID.to_csv(file_path, index=False)
